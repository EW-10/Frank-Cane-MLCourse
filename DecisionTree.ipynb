# %% [markdown]
# # Decison Trees

# %% [markdown]
# First we'll load some fake data on past hires I made up. Note how we use pandas to convert a csv file into a DataFrame:

# %%
# Importing libraries:
import numpy as np
import pandas as pd
from sklearn import tree

input_file = "C:\MLCourse\PastHires.csv"
df = pd.read_csv(input_file, header = 0)

# %%
df.head()
# Out:
#    Years Experience Employed?  Previous employers Level of Education  \
# 0                10         Y                   4                 BS
# 1                 0         N                   0                 BS
# 2                 7         N                   6                 BS
# 3                 2         Y                   1                 MS
# 4                20         N                   2                PhD
#
#   Top-tier school Interned Hired
# 0               N        N     Y
# 1               Y        Y     Y
# 2               N        N     N
# 3               Y        N     Y
# 4               Y        N     N

# %% [markdown]
# scikit-learn needs everything to be numerical for decision trees to work. So, we'll map Y,N to 1,0 and levels of education to some scale of 0-2. In the real world, you'd need to think about how to deal with unexpected or missing data! By using map(), we know we'll get NaN for unexpected values.

# %%
d = {'Y': 1, 'N': 0}

# Below I create an "alternate universe", where people normally hired are not and vice-versa.

e = {'Y':0, 'N':1}
df['Hired'] = df['Hired'].map(e)

df['Employed?'] = df['Employed?'].map(d)
df['Top-tier school'] = df['Top-tier school'].map(d)
df['Interned'] = df['Interned'].map(d)
d = {'BS': 0, 'MS': 1, 'PhD': 2}
df['Level of Education'] = df['Level of Education'].map(d)
df.head()
# Out:
#    Years Experience  Employed?  Previous employers  Level of Education  \
# 0                10          1                   4                   0
# 1                 0          0                   0                   0
# 2                 7          0                   6                   0
# 3                 2          1                   1                   1
# 4                20          0                   2                   2
#
#    Top-tier school  Interned  Hired
# 0                0         0      0
# 1                1         1      0
# 2                0         0      1
# 3                1         0      0
# 4                1         0      1

# %% [markdown]
# Next we need to separate the features from the target column that we're trying to bulid a decision tree for.

# %%
features = list(df.columns[:6])
features
# Out:
# ['Years Experience',
#  'Employed?',
#  'Previous employers',
#  'Level of Education',
#  'Top-tier school',
#  'Interned']

# %% [markdown]
# Now actually construct the decision tree:

# %%
y = df["Hired"]
X = df[features]
clf = tree.DecisionTreeClassifier()
clf = clf.fit(X,y)

# %%
from matplotlib import pyplot as plt
# from sklearn import datasets
# from sklearn.tree import DecisionTreeClassifier 
# from sklearn import tree
text_representation = tree.export_text(clf)
print(text_representation)
# Out:
# |--- feature_1 <= 0.50
# |   |--- feature_5 <= 0.50
# |   |   |--- feature_2 <= 0.50
# |   |   |   |--- feature_4 <= 0.50
# |   |   |   |   |--- class: 1
# |   |   |   |--- feature_4 >  0.50
# |   |   |   |   |--- class: 0
# |   |   |--- feature_2 >  0.50
# |   |   |   |--- class: 1
# |   |--- feature_5 >  0.50
# |   |   |--- class: 0
# |--- feature_1 >  0.50
# |   |--- class: 0

# %%
fig = plt.figure(figsize=(25,20))
_ = tree.plot_tree(clf, 
                   feature_names=features,  
                   class_names=["N","Y"],
                   filled=True)

# %% [markdown]
# ... and display it. Note you need to have pydotplus installed for this to work. (!pip install pydotplus)
#
# To read this decision tree, each condition branches left for "true" and right for "false". When you end up at a value, the value array represents how many samples exist in each target value. So value = [0. 5.] mean there are 0 "no hires" and 5 "hires" by the tim we get to that point. value = [3. 0.] means 3 no-hires and 0 hires.

# %% [markdown]
# **<u>Note:</u>** Running the code below raises the following error --
#
# **InvocationException**: Program terminated with status: 1. stderr follows: 'C:\Users\E' is not recognized as an internal or external command,
# operable program or batch file.
#
# from IPython.display import Image
# ####### from sklearn.externals.six import StringIO
# from io import StringIO
# import pydotplus
#
# dot_data = StringIO()
# tree.export_graphviz(clf, out_file=dot_data,
#                          feature_names=features)
# graph = pydotplus.graph_from_dot_data(dot_data.getvalue())
# Image(graph.create_png())

# %% [markdown]
# ## Ensemble learning: using a random forest

# %% [markdown]
# We'll use a random forest of 10 decision trees to predict employment of specific candidate profiles:

# %%
from sklearn.ensemble import RandomForestClassifier

clf = RandomForestClassifier(n_estimators=10)
clf = clf.fit(X, y)

#Predict employment of an employed 10-year veteran
print (clf.predict([[10, 1, 4, 0, 0, 0]]))
#...and an unemployed 10-year veteran
print (clf.predict([[10, 0, 4, 0, 0, 0]]))
# Out:
# [0]
# [0]
# C:\Users\Einat Willmott\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# C:\Users\Einat Willmott\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(

# %% [markdown]
# **0** means the person above does not get hired, and **1** means the person gets hired.
#
# **Please note** I have reversed the *Hire* data in the original dataset to reflect an alternate universe where people who are normally hired are **not** and vice-versa; and this affects the predictions above for these two hypthetical candidates.
#
# **Please also note** that random forests have a **<u>random</u>** component, hence running this notebook multiple times, without setting a seed, may create different predictions for these two hypothetical candidates, even though the same dataset is used to train the model.

# %% [markdown]
# ## Activity

# %% [markdown]
# Modify the test data to create an alternate universe where everyone I hire everyone I normally wouldn't have, and vice versa. Compare the resulting decision tree to the one from the original data.

# %% [markdown]
# **<u>Done.</u>**
